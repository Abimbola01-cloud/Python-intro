# %%
print("Hello world!")
# Out:
# Hello world!

# %%
# Thursday, 23rd July 2026
print("=" * 60)
print("     PYTHON LEARNER IDENTITY CARD")
print("=" * 60)

full_name  = input("What is your full name?")
Age = input("How old are you?")
Country = input("What country are you from?")
Focus = input("What is your favourite course?")
Goal = input("What is your goal as a Python learner?")

print("Name     :", full_name )
print("Age      :", Age)
print("Country  :", Country)
print("Focus    :", Focus)
print("Goal     :", Goal)

print("-" * 60)
print("     Every expert was once a beginner.")
print("-" * 60)
# Out:
# ============================================================
#      PYTHON LEARNER IDENTITY CARD
# ============================================================
# Name     : Abimbola Tiamiyu
# Age      : 20
# Country  : Canada
# Focus    : Data Science
# Goal     : Build a data dashboard
# ------------------------------------------------------------
#      Every expert was once a beginner.
# ------------------------------------------------------------
